# %%
import numpy as np

# %%
# buat vector i dengan elemen (1,0) dan vector j dengan elemen (0,1)
i = np.array([1, 0])
j = np.array([0, 1])

# Menampilkan hasil
print("Vektor i:", i)
print("Vektor j:", j)
# Out:
# Vektor i: [1 0]
# Vektor j: [0 1]

# %%
# buktikan bahwa vector i dan vector j itu orthogonal
dot_ij = np.dot(i, j)

# %%
# vector v=(1,2) dan w=(2,-1)
v = np.array([1, 2])
w = np.array([2, -1])

# Menampilkan hasil
print("Vector v:", v)
print("Vector w:", w)
# Out:
# Vector v: [1 2]
# Vector w: [ 2 -1]

# %%
# cek apakah v dan w orthogonal
dot_vw = np.dot(v, w)

print("Dot product i . j =", dot_ij)
print("Orthogonal (i, j):", dot_ij == 0)

print("\nDot product v . w =", dot_vw)
print("Orthogonal (v, w):", dot_vw == 0)
# Out:
# Dot product i . j = 0
# Orthogonal (i, j): True
#
# Dot product v . w = 0
# Orthogonal (v, w): True
